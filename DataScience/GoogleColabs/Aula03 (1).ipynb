# %% [markdown]
# *texto em itálico*

# %% [markdown]
# Resumo:
#
# (Quando quiser ajuda no codigo,usa a interrogação após o codigo)

# %% [markdown]
# ##Sempre abrir arquivos

# %%
import pandas as pd

# %% [markdown]
# ## Visualizar dados
# * head (Exibir dados)
# * tail (cauda)
# * index
# * describe (quartil)
# * transposta

# %%
#pd.read_csv?

#Importar arquivo
#Informar que a separação é por ponto e virgula.. normalmente é lido com virgulas...
covid_df = pd.read_csv("/content/covid2022.csv", sep = ";")
covid_df
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
#covid_df[colunas : linhas]
covid_df[:5]
#Abrindo as n primeiras linhas
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2022-07-01         26       210147125.0        32434063       76045
# 1  2022-07-02         26       210147125.0        32471847       37784
# 2  2022-07-03         27       210147125.0        32490422       18575
# 3  2022-07-04         27       210147125.0        32535923       45501
# 4  2022-07-05         27       210147125.0        32610514       74591
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %%
#Excluir os dados faltantes (NaN)
covid_limpo = covid_df.dropna()
covid_limpo 
#Não vai mostrar nada pois em alguma coluna em TODAS as linhas está faltando algo
# Out:
# Empty DataFrame
# Columns: [regiao, estado, municipio, coduf, codmun, codRegiaoSaude, nomeRegiaoSaude, data, semanaEpi, populacaoTCU2019, casosAcumulado, casosNovos, obitosAcumulado, obitosNovos, Recuperadosnovos, emAcompanhamentoNovos, interior/metropolitana]
# Index: []

# %%
#Salvar arquivo em novo nome, ou nova extensão (.to_)
covid_df.to_csv("NovoNomeArquivo.csv")
#Pode transformar em sql, json...

# %%
#Ultimas linhas = tail (calda) -> Se n informar nada, pega apenas as ultimas 5
covid_df.tail(10)
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 471986  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471987  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471988  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471989  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471990  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 471986  DISTRITO FEDERAL  2022-09-13         37         3015268.0
# ...

# %%
#indice do arquivo
covid_df.index
# Out:
# RangeIndex(start=0, stop=471996, step=1)

# %%
#Pegar nome das colunas
covid_df.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
covid_df.describe()
# Out:
#                coduf         codmun  codRegiaoSaude      semanaEpi  \
# count  471996.000000  469644.000000   467880.000000  471996.000000
# mean       32.360384  325258.014130    32403.123698      32.214286
# std         9.873307   98535.129104     9836.351818       3.481490
# min        11.000000  110000.000000    11001.000000      26.000000
# 25%        25.000000  251200.000000    25010.000000      29.000000
# 50%        31.000000  314610.000000    31059.000000      32.000000
# 75%        41.000000  411915.000000    41015.000000      35.000000
# max        76.000000  530010.000000    53001.000000      38.000000
#
#        populacaoTCU2019  casosAcumulado     casosNovos  obitosAcumulado  \
# count      4.702320e+05    4.719960e+05  471996.000000    471996.000000
# mean       1.126190e+05    1.810664e+04      14.355865       363.115107
# std        2.935317e+06    4.701238e+05     511.199512      9572.018291
# min        7.810000e+02    0.000000e+00  -30211.000000         0.000000
# ...

# %%
#Trocar as colunas por linhas (Transpor)
covid_df.T
# Out:
#                              0            1            2            3       \
# regiao                       Brasil       Brasil       Brasil       Brasil
# estado                          NaN          NaN          NaN          NaN
# municipio                       NaN          NaN          NaN          NaN
# coduf                            76           76           76           76
# codmun                          NaN          NaN          NaN          NaN
# codRegiaoSaude                  NaN          NaN          NaN          NaN
# nomeRegiaoSaude                 NaN          NaN          NaN          NaN
# data                     2022-07-01   2022-07-02   2022-07-03   2022-07-04
# semanaEpi                        26           26           27           27
# populacaoTCU2019        210147125.0  210147125.0  210147125.0  210147125.0
# casosAcumulado             32434063     32471847     32490422     32535923
# ...

# %%
#Seleçao pelo nome do estado
covid_df["estado"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 471991     DF
# 471992     DF
# 471993     DF
# 471994     DF
# 471995     DF
# Name: estado, Length: 471996, dtype: object

# %%
#Seleçao pelo nome de mais de uma coluna
covid_df[["estado", "obitosAcumulado", "municipio"]]
# Out:
#        estado  obitosAcumulado municipio
# 0         NaN           671700       NaN
# 1         NaN           671858       NaN
# 2         NaN           671911       NaN
# 3         NaN           672033       NaN
# 4         NaN           672429       NaN
# ...       ...              ...       ...
# 471991     DF            11825  Brasília
# 471992     DF            11825  Brasília
# 471993     DF            11828  Brasília
# 471994     DF            11829  Brasília
# 471995     DF            11829  Brasília
#
# [471996 rows x 3 columns]

# %%
# Indexação booleana
#loc - especificar as linhas e colunas que vc quer
#covid_df.loc[LINHAS de:até , [COLUNAS]]
covid_df.loc[4150:4169 , ["regiao", "estado", "municipio", "obitosAcumulado", "data"]]
# Out:
#      regiao estado            municipio  obitosAcumulado        data
# 4150  Norte     RO  Santa Luzia D'Oeste               26  2022-08-04
# 4151  Norte     RO  Santa Luzia D'Oeste               26  2022-08-05
# 4152  Norte     RO  Santa Luzia D'Oeste               26  2022-08-06
# 4153  Norte     RO  Santa Luzia D'Oeste               26  2022-08-07
# 4154  Norte     RO  Santa Luzia D'Oeste               26  2022-08-08
# 4155  Norte     RO  Santa Luzia D'Oeste               26  2022-08-09
# 4156  Norte     RO  Santa Luzia D'Oeste               26  2022-08-10
# 4157  Norte     RO  Santa Luzia D'Oeste               27  2022-08-11
# 4158  Norte     RO  Santa Luzia D'Oeste               27  2022-08-12
# 4159  Norte     RO  Santa Luzia D'Oeste               27  2022-08-13
# 4160  Norte     RO  Santa Luzia D'Oeste               27  2022-08-14
# 4161  Norte     RO  Santa Luzia D'Oeste               27  2022-08-15
# 4162  Norte     RO  Santa Luzia D'Oeste               27  2022-08-16
# ...

# %%
#Selecionar a linha com o iloc
covid_df.iloc[7000]
# Out:
# regiao                         Norte
# estado                            AC
# municipio                  Brasiléia
# coduf                             12
# codmun                      120010.0
# codRegiaoSaude               12001.0
# nomeRegiaoSaude            ALTO ACRE
# data                      2022-07-29
# semanaEpi                         30
# populacaoTCU2019             26278.0
# casosAcumulado                  3882
# casosNovos                         9
# obitosAcumulado                   50
# obitosNovos                        0
# Recuperadosnovos                 NaN
# emAcompanhamentoNovos            NaN
# interior/metropolitana           0.0
# Name: 7000, dtype: object

# %%
#Selecionar a linha com o iloc como dataframe
covid_df.iloc[[3000]]
# Out:
#      regiao estado   municipio  coduf    codmun  codRegiaoSaude  \
# 3000  Norte     RO  Corumbiara     11  110007.0         11006.0
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 3000        CONE SUL  2022-08-30         35            7391.0            2168
#
#       casosNovos  obitosAcumulado  obitosNovos  Recuperadosnovos  \
# 3000           0               25            0               NaN
#
#       emAcompanhamentoNovos  interior/metropolitana
# 3000                    NaN                     0.0

# %%
#O iloc pode ser passado como uma matriz, "Filtro"
#covid_df.iloc[linhas: , coluna2:coluna3]
covid_df.iloc[9850:9900 , 3:7]

#covid_filtro = covid_df.iloc[9850:9900 , 3:7]_to (pra salvar essa nova tabela com um filtro)
# Out:
#       coduf    codmun  codRegiaoSaude       nomeRegiaoSaude
# 9850     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9851     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9852     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9853     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9854     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9855     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9856     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9857     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9858     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9859     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9860     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9861     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9862     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9863     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# 9864     13  130083.0         13002.0  RIO NEGRO E SOLIMOES
# ...

# %% [markdown]
# ## Indexação booleanda

# %%
#Selecionar o codigo do estado - filtro
covid_df[covid_df['coduf'] == 23]
# Out:
#          regiao estado        municipio  coduf    codmun  codRegiaoSaude  \
# 840    Nordeste     CE              NaN     23       NaN             NaN
# 841    Nordeste     CE              NaN     23       NaN             NaN
# 842    Nordeste     CE              NaN     23       NaN             NaN
# 843    Nordeste     CE              NaN     23       NaN             NaN
# 844    Nordeste     CE              NaN     23       NaN             NaN
# ...         ...    ...              ...    ...       ...             ...
# 93151  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93152  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93153  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93154  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
# 93155  Nordeste     CE  Viçosa do Ceará     23  231410.0         23013.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
covid_df[covid_df['codmun'] == 230440]
# Out:
#          regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 82572  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82573  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82574  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82575  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82576  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# ...         ...    ...        ...    ...       ...             ...
# 82651  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82652  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82653  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82654  Nordeste     CE  Fortaleza     23  230440.0         23001.0
# 82655  Nordeste     CE  Fortaleza     23  230440.0         23001.0
#
#            nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 82572  1ª REGIAO FORTALEZA  2022-07-01         26         2669342.0
# ...

# %%
#Selecionando vários codigo do estado
covid_df[(covid_df['coduf'] > 22) & (covid_df['coduf'] < 27)]
# Out:
#           regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 840     Nordeste     CE       NaN     23       NaN             NaN
# 841     Nordeste     CE       NaN     23       NaN             NaN
# 842     Nordeste     CE       NaN     23       NaN             NaN
# 843     Nordeste     CE       NaN     23       NaN             NaN
# 844     Nordeste     CE       NaN     23       NaN             NaN
# ...          ...    ...       ...    ...       ...             ...
# 141703  Nordeste     PE     Xexéu     26  261650.0         26008.0
# 141704  Nordeste     PE     Xexéu     26  261650.0         26008.0
# 141705  Nordeste     PE     Xexéu     26  261650.0         26008.0
# 141706  Nordeste     PE     Xexéu     26  261650.0         26008.0
# 141707  Nordeste     PE     Xexéu     26  261650.0         26008.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 840                NaN  2022-07-01         26         9132078.0
# ...

# %% [markdown]
# ## Operações

# %%
# Media de uma coluna, dado específico = mean

# %%
covid_df['casosNovos'].mean()
# Out:
# 14.355865303943254

# %%
mediaObitosAcumulados = covid_df['obitosAcumulado'].mean()
print(f"Sua media de casos acumulados é de {mediaObitosAcumulados:.2f}")
# Out:
# Sua media de casos acumulados é de 363.12

# %%
#Entradas por estado
covid_df['estado'].value_counts()
# Out:
# MG    71820
# SP    54348
# RS    41916
# BA    35196
# PR    33684
# SC    24948
# GO    20832
# PI    18984
# PB    18900
# MA    18396
# PE    15708
# CE    15624
# RN    14196
# PA    12180
# MT    12012
# TO    11844
# AL     8736
# RJ     7896
# MS     6720
# ES     6720
# SE     6468
# AM     5292
# RO     4536
# AC     1932
# AP     1428
# RR     1428
# DF      168
# Name: estado, dtype: int64

# %%
#Entradas nopvas por estado, percentual
covid_df['estado'].value_counts(normalize=True)
# Out:
# MG    0.152189
# SP    0.115166
# RS    0.088822
# BA    0.074582
# PR    0.071378
# SC    0.052866
# GO    0.044144
# PI    0.040228
# PB    0.040050
# MA    0.038982
# PE    0.033286
# CE    0.033108
# RN    0.030082
# PA    0.025810
# MT    0.025454
# TO    0.025098
# AL    0.018512
# RJ    0.016732
# MS    0.014240
# ES    0.014240
# SE    0.013706
# AM    0.011214
# RO    0.009612
# AC    0.004094
# AP    0.003026
# RR    0.003026
# DF    0.000356
# Name: estado, dtype: float64

# %%
def soma(x,y):
  s = x+y
  return s

##Funcao anônima
  lambda x,y: x+y

# %%
#Ele traz pra o maior valor de casos novos e obitos
#apply = aplicar uma função
#função = (lambda x: x.max())
covid_df[["casosNovos" , "obitosNovos"]].apply(lambda x: x.max())
# Out:
# casosNovos     107959
# obitosNovos       762
# dtype: int64

# %%
#Ordenar uma série = coluna
covid_df['estado'].sort_values(ascending=True)
# Out:
# 8149     AC
# 7553     AC
# 7554     AC
# 7555     AC
# 7556     AC
#        ...
# 79      NaN
# 80      NaN
# 81      NaN
# 82      NaN
# 83      NaN
# Name: estado, Length: 471996, dtype: object

# %%
#Ordenar dataFrame = tabela inteira
covid_df.sort_values(by='estado', ascending = True)
# Out:
#       regiao estado            municipio  coduf    codmun  codRegiaoSaude  \
# 8149   Norte     AC  Santa Rosa do Purus     12  120043.0         12002.0
# 7553   Norte     AC               Jordão     12  120032.0         12002.0
# 7554   Norte     AC               Jordão     12  120032.0         12002.0
# 7555   Norte     AC               Jordão     12  120032.0         12002.0
# 7556   Norte     AC               Jordão     12  120032.0         12002.0
# ...      ...    ...                  ...    ...       ...             ...
# 79    Brasil    NaN                  NaN     76       NaN             NaN
# 80    Brasil    NaN                  NaN     76       NaN             NaN
# 81    Brasil    NaN                  NaN     76       NaN             NaN
# 82    Brasil    NaN                  NaN     76       NaN             NaN
# 83    Brasil    NaN                  NaN     76       NaN             NaN
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# ## Graficos

# %%
#Exibir uma serie com grafico em linha
covid_df['estado'].value_counts().plot()

# %%
#Grafico em barras
covid_df['estado'].value_counts().plot(kind = 'hist')

# %%
#Grafico em barras
covid_df['estado'].value_counts().plot(kind = 'bar')
