# %%
import pandas as pd

covid = pd.read_csv("/content/HIST_PAINEL_COVIDBR_2022_Parte2_22set2022 (1).csv", sep = ';')
covid_df = pd.DataFrame(covid)
display(covid_df)
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
#Salvar/exportar a Planilha no computador

covid.to_csv("Minha tabela COVID.csv")

# %%
#Ultimas 5 linhas da tabela (tail = cauda) -> default (mas pode dizer quantas linhas quer no parenteses)
covid.tail()
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 471991  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471992  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471993  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471994  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 471995  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 471991  DISTRITO FEDERAL  2022-09-18         38         3015268.0
# 471992  DISTRITO FEDERAL  2022-09-19         38         3015268.0
# 471993  DISTRITO FEDERAL  2022-09-20         38         3015268.0
# 471994  DISTRITO FEDERAL  2022-09-21         38         3015268.0
# 471995  DISTRITO FEDERAL  2022-09-22         38         3015268.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 471991          838413           0            11825            0
# ...

# %%
covid.index
# Out:
# RangeIndex(start=0, stop=471996, step=1)

# %%
#Ver o nome das colunas
covid.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
#Selecionar dados 
covid[['estado', 'municipio', 'casosNovos', 'obitosNovos']]
# Out:
#        estado municipio  casosNovos  obitosNovos
# 0         NaN       NaN       76045          284
# 1         NaN       NaN       37784          158
# 2         NaN       NaN       18575           53
# 3         NaN       NaN       45501          122
# 4         NaN       NaN       74591          396
# ...       ...       ...         ...          ...
# 471991     DF  Brasília           0            0
# 471992     DF  Brasília          88            0
# 471993     DF  Brasília          29            3
# 471994     DF  Brasília          43            1
# 471995     DF  Brasília          46            0
#
# [471996 rows x 4 columns]
# ...
